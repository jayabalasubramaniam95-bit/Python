# %%
from ClassLibrary import SubfieldsInAI

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from ClassLibrary import OddEven
OddEven.OddEven()
# Out:
# Enter the number:  45
# '45 is Odd Number'

# %%
from ClassLibrary import ElegiblityForMarriage
ElegiblityForMarriage.Elegible()
# Out:
# Your Gender: F
# Your Age: 17
# 'NOT ELIGIBLE'

# %%
from ClassLibrary import FindPercent
FindPercent.percentage()
# Out:
# Subject1:  90
# Subject2:  99
# Subject3:  96
# Subject4:  95
# Subject5:  94
# Total: 471
# Percentage:  94.2
# 94.2

# %%
from ClassLibrary import triangle
triangle.triangle()
# Out:
# Height:  19
# Breadth:  18
# Area of Triangle:  171.0
# Height1:  10
# Height2:  14
# Breadth:  16
# Perimeter of Triangle:  40.0
