# %%
print("Hope AI")
# Out:
# Hope AI

# %%
print("Enter your institute name? : ", input())
# Out:
#  HOPE AI
# Enter your institute name? :  HOPE AI

# %%
print("Enter your name:  ", input())
print("Enter your age: ", input())
print("Enter your school name: ", input())
print("Enter your drgree:", input())
# Out:
#  Raj
# Enter your name:   Raj
#  15
# Enter your age:  15
#   Guru school
# Enter your school name:   Guru school
#  B.E CSE
# Enter your drgree: B.E CSE

# %%
print("Enter your name:  ")
input()
print("Enter your age: ")
input()
print("Enter your school name: ")
input()
print("Enter your drgree:")
input()
# Out:
# Enter your name:
#  Raj
# Enter your age:
#  15
# Enter your school name:
#  Guru school
# Enter your drgree:
#  B.E CSE
# 'B.E CSE'

# %%
a=43
print("a=",a)
b=34
print("b=",b)
add = a+b
print("Add=", add)
# Out:
# a= 43
# b= 34
# Add= 77

# %%
a=43
print("a=",a)
b=34
print("b=",b)
sub = a-b
print("Sub=", sub)
# Out:
# a= 43
# b= 34
# Sub= 9

# %%
a=63
print("a=",a)
b=97
print("b=",b)
mul = a*b
print("Mul=", mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
a=76
print("a=",a)
b=31
print("b=",b)
div = a/b
print("Float Div=", div)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
a=76
print("a=",a)
b=31
print("b=",b)
div =int( a/b)
print("Float Div=", div)
# Out:
# a= 76
# b= 31
# Float Div= 2

# %%
a=76
print("a=",a)
b=31
print("b=",b)
div =int( a%b)
print("Modulo=", div)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
a=4
b=4
print("a=",a)
print("b=",b)
print("power", pow(a,b))
# Out:
# a= 4
# b= 4
# power 256
