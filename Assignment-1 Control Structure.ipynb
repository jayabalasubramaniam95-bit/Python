# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
Add = Num1+Num2
print("Num1", Num1)
print("Num2", Num2)
print("Add", Add)
# Out:
# Num1 10
# Num2 30
# Add 40

# %%
print("Enter the BMI Index:")
index= int(input())
if(index<18):
  print("Under weight")
elif(index<24):
  print("Normal range")
else:
  print("Very Overweight")
# Out:
# Enter the BMI Index:
#  34
# Very Overweight

# %%
Lists = [12,21,28,34,50]
for index in Lists:
  if(index<18):
    print("Under weight")
  elif(index<24):
    print("Normal range")
  else:
    print("Very Overweight")
# Out:
# Under weight
# Normal range
# Very Overweight
# Very Overweight
# Very Overweight
