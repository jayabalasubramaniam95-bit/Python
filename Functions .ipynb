# %%
def fnHealthCheck():
 Lists=[12,23,35,55,24,12]
 for i in Lists:
     if(i<18):
       print("Under weight")
     elif(i<24):
       print("Normal range")
     else:
       print("Very Overweight")

# %%
fnHealthCheck()
# Out:
# Under weight
# Normal range
# Very Overweight
# Very Overweight
# Very Overweight
# Under weight

# %%
def fnAdd(a,b):
    add= a+b
    return add

# %%
fnAdd(13,17)
# Out:
# 30

# %%
def fnHealthCheck(i):
     if(i<18):
       print("Under weight")
       Msg="Under weight"
     elif(i<24):
       Msg="Normal range"
       print("Normal range")
     else:
       Msg="Very Overweight"
       print("Very Overweight")
     return Msg

# %%
fnHealthCheck(17)
# Out:
# Under weight
# 'Under weight'

# %%
def fnOddOrEven():
    num=int(input("Enter the number: "))
    if(num%2==0):
      Msg=0
    else:
      Msg=1
    return Msg

# %%
Messgae = int(fnOddOrEven())
# Out:
# Enter the number:  13

# %%
if(Messgae == 0):
 print("Even")
else:
 print("Odd")
# Out:
# Odd

# %%
def  fnBMI():
    BMI=int(input("Enter the BMI Index: "))
    if(BMI<18.5):
      print('under weight')
      msg='Under weight'
    elif(BMI<24.9):
      print('Normal')
      msg='Normal'  
    elif(BMI<29.9):
      print('OverWeight')
      msg='Overweight'
    else:
      print('Very overweight')
      msg='Very Overweight'
    return msg

# %%
fnBMI()
# Out:
# Enter the BMI Index:  31
# Very overweight

# %%
Message = fnBMI()
print(Message)
# Out:
# Enter the BMI Index:  18
# under weight
# Under weight

# %%
def addition (a, b):
    add= a+b
    return add

# %%
addition(10,20)
# Out:
# 30
