# %%
age=int(input("Enter User Age"))
if(age > 17):
    print("Eligible to vote")
else:
    print("Not Eligible to vote")
# Out:
# Enter User Age 34
# Eligible to vote

# %%
List=[23,56,12,99,45,23]
sl=sorted(List)
print(sl[-1])
# Out:
# 99

# %%
List=[23,56,12,99,45,23]
sl=sorted(List, reverse = True)
print(sl[0])
# Out:
# 99

# %%
nums = [-5, 3, -1, 4,1.2]
sorted(nums, key=abs)
# Out:
# [-1, 1.2, 3, 4, -5]

# %%
dictionary={'e1':10000, 'e2':60000}
print(dictionary.items())
for key,value in dictionary.items():
    if(value >50000):
       print(key, " is Eligible for 10% Bonus")
    else:
        print(key, " is not Eligible for 10% Bonus")
# Out:
# dict_items([('e1', 10000), ('e2', 60000)])
# e1  is not Eligible for 10% Bonus
# e2  is Eligible for 10% Bonus

# %%
num=int(input('Enter the Number'))
if(num % 2==0):
    print('The Given number is Even')
else:
     print('The Given number is Odd')
# Out:
# Enter the Number 12
# The Given number is Even

# %%
sen= (input('Enter the sentence'))
print((sen[::-1]))
# Out:
# Enter the sentence Enter the Number
# rebmuN eht retnE

# %%
sen= (input('Enter the sentence'))
txt=''.join(reversed(sen))
print(txt)
# Out:
# Enter the sentence lool
# lool

# %%
dictionary={'s1':69, 's2':99, 's3':34, 's4':45, 's5':25}
for student, mark in dictionary.items():
    if(mark >= 40):
        print(student," is Pass")
    else:
        print(student," is Fail")
# Out:
# s1  is Pass
# s2  is Pass
# s3  is Fail
# s4  is Pass
# s5  is Fail

# %%
camount=float(input('Enter order amount'))
if(camount>= 100):
    camount= (camount -(camount *0.20))
print('Final Amount to be paid is : ', camount)
# Out:
# Enter order amount 20
# Final Amount to be paid is :  20.0

# %%
dictionary={'u1':400, 's2':1000, 's3':200, 's4':10000, 's5':2000}
userId=input('Enter Used Id')
amountWidthdraw=int(input('Enter the amount'))
for user, balance in dictionary.items():
    if(userId==user):
        if(balance<500):
          print("Minimum balace. Unable to withdrw the amount from your account")
        else:
            if((balance<amountWidthdraw) or ((balance-amountWidthdraw) <500)):
              print('amount is exceed from balance')
            else:                               
        
               balance= balance- amountWidthdraw
               print('amount Widthdraw successfully')
# Out:
# Enter Used Id s2
# Enter the amount 1
# amount Widthdraw successfully

# %%
year =int(input('Enter the Year'))
if( year%400 ==0 or (year%4 ==0 and  year%100 !=0)):
    print(str(year) +' is Leap year')
else:
      print(str(year) +' is not Leap year')
# Out:
# Enter the Year 2026
# 2026 is not Leap year

# %%
List=[2,3,5,6,8,10,13, 17,22]
print(f)
